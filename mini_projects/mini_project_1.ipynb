# %% [markdown]
# # Time Series Analysis - Mini-project 1
# ## Introduction
# This is a voluntary mini-project that aims to get you started using Python. You complete it on your
# own and you do not need to hand in anything after completing it; it is just meant to get you started.
# Before you begin:
# - View the online videos related to stochastic vectors and stochastic processes, as well as read
# chapters 1, 2, and 3.1-3.3 in the course textbook.
# - Install Python and the course Python package from https://github.com/andreasjak/TimeSeriesAnalysis.

# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np
import soundfile as sf
from IPython.display import Audio

# Import tsa_lth package
import os
import sys
# Add path to tsa_lth library
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', 'TimeSeriesAnalysis-main', 'TimeSeriesAnalysis-main')))
from tsa_lth.analysis import acf

# %% [markdown]
# ## Task 1
# First, we load the file 'fa.wav' into Python using the package soundfile.

# %%
try:
    filepath = "../data/fa.wav"
    y, Fs = sf.read(filepath)
    print(f"Successfully loaded file. Sampling rate (Fs): {Fs} Hz")
    print(f"Signal (y) has {len(y)} samples.")
except Exception as e:
    print("Could not find 'fa.wav' in '../data/'")

# %% [markdown]
# ## Task 1 Continued
# The signal is now stored in the variable y, whereas the signal’s sampling rate is stored in Fs. The
# data file is the sampled speech of a female voice saying ”Why were you away a year, Roy?”. Plot
# the signal using matplotlib (aliased as plt). Can you tell which part of the signal constitutes which word?
# If you like, you can listen to the signal by using the function Audio:

# %%
# Listen to the signal
Audio(data=y, rate=Fs)

# %%
# Write code to plot the signal

# %% [markdown]
# ## Task 2
# Now, extract about 200 samples from one of the vowels and plot the result. Examining the signal,
# the result should appear periodic – in fact, tonal audio is often modelled as a sum of sinusoids.
# Use the function acf that was imported earlier and plot the results. Can you determine the
# main periodicity in the vowel? Which frequency does this periodicity correspond to? Hint: recall
# Example 3.8 in the textbook.

# %%
# Write code to extract ~200 samples from one of the vowels

# %% [markdown]
# ## Task 3 (optional)
# As you may know from other courses, and as you learned when you could not resist reading
# chapter 3.6 while you were at it, one often estimates the power spectral density to get a better
# feeling for the frequency content of a signal. Can you determine the fundamental frequency of
# the vowel better this way? Do you get a better estimate if you zeropadd the signal? Hint: recall
# Example 3.16 in the textbook.
