# %% [markdown]
# # Time Series Analysis - Mini-project 2
# ## Introduction
# This is a voluntary mini-project that aims to examine how one can simulate AR, MA, and ARMA
# processes, as well as examine the corresponding ACF and PACF of these processes. You complete
# it on your own and you do not need to hand in anything after completing it; it is just meant to get
# you started.
#
# Before you begin:
# - View the online videos related to stochastic process and identification, as well as read chapters 3 and 4.1-4.2 in the course textbook.
# - Install Python and the course Python package from https://github.com/andreasjak/TimeSeriesAnalysis. The data file for this assignment, `Miniproject2data.mat`, is in the `data` folder.

# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
import scipy.io

# Import tsa_lth package
import os
import sys
# Add path to tsa_lth library
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', 'TimeSeriesAnalysis-main', 'TimeSeriesAnalysis-main')))
from tsa_lth.analysis import acf, pacf, plotACFnPACF, pzmap

# %% [markdown]
# ## Task 1
# Generate $N = 10000$ samples of an AR, MA, and ARMA process with the $A(z)$ and $C(z)$ polynomials
#
# $$A(z) = 1 - 1.79z^{-1} + 0.84z^{-2}$$
# $$C(z) = 1 - 0.81z^{-1} - 0.11z^{-2}$$
#
# You can do this by first generating a white Gaussian noise using `np.random.randn` and then use
# `signal.lfilter` to shape the noise to the different processes. Plot the resulting realisations
# using `plt.plot`. Use the provided `acf` and `pacf` functions (or `plotACFnPACF`) and plot the ACF and PACF
# for each of the processes. Check if the result corresponds to your expectations - are you able to
# identify the correct models? Try reducing the number of samples to $N = 100$. Can you identify
# the models correctly?

# %%
A = np.array([1, -1.79, 0.84])
C = np.array([1, -0.81, -0.11])
N = 10000

# Write code to simulate the AR, MA, and ARMA processes

# %%
# Write code to plot the realisations and their ACF and PACF

# %% [markdown]
# ## Task 2
# Try changing the $A(z)$ and $C(z)$ polynomials such that one of the polynomials at a time have a
# root outside the unit circle. The function `np.roots` can be used to compute the roots of a polynomial, and
# `pzmap` shows the poles and zeros. Plot the resulting realisations using `plt.plot`. Which polynomial may have a root
# outside the unit circle without causing instability?

# %%
# Write code to examine polynomials with a root outside the unit circle

# %% [markdown]
# ## Task 3
# Load the provided data set and examine what might be an appropriate model structure for this data set.

# %%
# Load the data set
y = scipy.io.loadmat('../data/Miniproject2data.mat')['y'].flatten()
print(f"Loaded {len(y)} samples.")

# %%
# Write code to examine a suitable model structure for the data

# %% [markdown]
# ## Comment
# You can find further details on how to write the required Python code in the first computer exercise
# (`labs/lab1.ipynb`). As you will see, by solving these tasks, you will also
# have solved part of this computer exercise.
